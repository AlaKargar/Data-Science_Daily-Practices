# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(["internet", "sleeping", "water", "food"])
y = np.array(["a few hours", "3-5 days", "a week","a month"])

# %%
plt.bar(x, y, color="blue", width=0.2)
plt.title("The time that humans can live without it: ")
plt.grid()
