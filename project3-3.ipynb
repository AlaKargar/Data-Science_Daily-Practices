# %%
import pandas as pd

# %%
data = {'Name':['Radan', 'Masih', 'Arisa'], 'Age': [225, 25, 28], 'Score': [6, 20, 19.5]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Score
# 0  Radan  225    6.0
# 1  Masih   25   20.0
# 2  Arisa   28   19.5
