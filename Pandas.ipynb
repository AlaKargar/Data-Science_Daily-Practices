# %%
import numpy as np
import pandas as pd

# %%
s= pd.Series([1, 4, 6, 6, 5, 12, 3], index= ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7'])

# %%
s.r2
# Out:
# np.int64(4)

# %%
s[1]
# Out:
# C:\Users\Ala\AppData\Local\Temp\ipykernel_9888\878419959.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[1]
# np.int64(4)

# %%
s.values
# Out:
# array([ 1,  4,  6,  6,  5, 12,  3])

# %%
s.index
# Out:
# Index(['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7'], dtype='object')

# %%
s.value_counts()
# Out:
# 6     2
# 1     1
# 4     1
# 5     1
# 12    1
# 3     1
# Name: count, dtype: int64

# %%
df= pd.DataFrame([[1,2], [3,4], [5,6]], index= ['r1', 'r2', 'r3'], columns= ['C1', 'C2'] )
df
# Out:
#     C1  C2
# r1   1   2
# r2   3   4
# r3   5   6

# %%
df[1:2]
# Out:
#     C1  C2
# r2   3   4

# %%
df[:2]
# Out:
#     C1  C2
# r1   1   2
# r2   3   4

# %%
df['C1']
# Out:
# r1    1
# r2    3
# r3    5
# Name: C1, dtype: int64

# %%
df.iloc[2, 1]
# Out:
# np.int64(6)

# %%
df.values
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
df[df > 1]
# Out:
#      C1  C2
# r1  NaN   2
# r2  3.0   4
# r3  5.0   6

# %%
df.index
# Out:
# Index(['r1', 'r2', 'r3'], dtype='object')

# %%
df.columns
# Out:
# Index(['C1', 'C2'], dtype='object')

# %%
df.head()
# Out:
#     C1  C2
# r1   1   2
# r2   3   4
# r3   5   6

# %%
df.tail(2)
# Out:
#     C1  C2
# r2   3   4
# r3   5   6

# %%
df.T #Transpose Columns to Rows
# Out:
#     r1  r2  r3
# C1   1   3   5
# C2   2   4   6

# %%
df.drop('r3', axis= 0)
# Out:
#     C1  C2
# r1   1   2
# r2   3   4

# %%
df.drop('C1', axis= 1)
# Out:
#     C2
# r1   2
# r2   4
# r3   6

# %%
df.describe()
# Out:
#         C1   C2
# count  3.0  3.0
# mean   3.0  4.0
# std    2.0  2.0
# min    1.0  2.0
# 25%    2.0  3.0
# 50%    3.0  4.0
# 75%    4.0  5.0
# max    5.0  6.0

# %%
df = pd.DataFrame({ 'r1':[1,4], 'r2':[2,5], 'r3':[3,6] })
df
# Out:
#    r1  r2  r3
# 0   1   2   3
# 1   4   5   6

# %%
data = {'Name': ['Ala', 'Scott', 'Jean'], 'Location': ['Iran', 'Saidasi', 'France'], 'Age': [18, 39, 36]}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name Location  Age
# 0    Ala     Iran   18
# 1  Scott  Saidasi   39
# 2   Jean   France   36

# %%
df.sort_index(axis= 1)
# Out:
#    Age Location   Name
# 0   18     Iran    Ala
# 1   39  Saidasi  Scott
# 2   36   France   Jean

# %%
df.sort_index(axis= 0, ascending= False)
# Out:
#     Name Location  Age
# 2   Jean   France   36
# 1  Scott  Saidasi   39
# 0    Ala     Iran   18

# %%
df.sort_values(by='Age')
# Out:
#     Name Location  Age
# 0    Ala     Iran   18
# 2   Jean   France   36
# 1  Scott  Saidasi   39

# %%
df[df.Age < 30]
# Out:
#   Name Location  Age
# 0  Ala     Iran   18

# %%
df.iloc[1][2]
# Out:
# C:\Users\Ala\AppData\Local\Temp\ipykernel_9888\65333983.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][2]
# np.int64(39)

# %%
df.iloc[1]['Age']
# Out:
# np.int64(39)

# %%
pd.DataFrame(np.random.randn(10,4))
# Out:
#           0         1         2         3
# 0 -1.233987 -1.086882 -0.755280 -0.700564
# 1  0.719359 -1.288903  0.413106  1.607012
# 2 -0.420172  0.083402 -1.219533 -0.845508
# 3  0.960672  0.765663 -2.068265 -0.172732
# 4 -1.397057  0.975996 -0.570593 -0.490021
# 5  1.222031  2.405088  0.263319  0.651765
# 6  0.697550 -0.103834  0.481093 -0.458982
# 7 -0.235613 -1.826222 -0.972118  0.404194
# 8  0.578067 -0.299389  0.465752 -0.052295
# 9  0.427860  0.518536 -0.800313  1.457523
