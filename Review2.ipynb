# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = {'نام':['Alla', 'Masih', 'Radan'], 'سن': [18, 26, 226], 'نمره' : [19, 20, 9]}

# %%
df = pd.DataFrame(data)
df
# Out:
#      نام   سن  نمره
# 0   Alla   18    19
# 1  Masih   26    20
# 2  Radan  226     9

# %%
grades = pd.Series([18, 26, 226], index = ['Alla', 'Masih', 'Radan'])
print(grades)
# Out:
# Alla      18
# Masih     26
# Radan    226
# dtype: int64

# %%
heights = np.random.randint(2000, 5000, 400)
df = pd.DataFrame({'ارتفاع کوه':heights})
mean_height = df['ارتفاع کوه'].mean()
print("میانگین ارتفاع کوه ها:", mean_height)
# Out:
# میانگین ارتفاع کوه ها: 3567.3575
