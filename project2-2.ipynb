# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
scores= np.array([7.4, 8.2, 7.6, 8.4, 8.8])
Ep= ["S1E1", "S2E1", "S3E1", "S4E1", "S5E1"]

# %%
plt.bar( Ep, scores, color= "purple", width=0.2)
plt.ylabel("Score")
plt.xlabel("Season of first episode")
plt.title("First episodes of Bungo Anime scores: ")
# Out:
# Text(0.5, 1.0, 'First episodes of Bungo Anime scores: ')
