# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([2,3,4])
a
# Out:
# array([2, 3, 4])

# %%
a[0]
# Out:
# np.int64(2)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.shape #Array kind
# Out:
# (3,)

# %%
b = np.array([(1,2), (3,4), (5,6)])
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b[1,1]
# Out:
# np.int64(4)

# %%
b[:, 1] #All of Rows
b[1:2, 1] #Since Row 0 to Row 2
# Out:
# array([4])

# %%
b[1,:] #All of Columns
# Out:
# array([3, 4])

# %%
b.ndim #How many Dimensiom?
# Out:
# 2

# %%
np.reshape(b,(2,3)) #Reshape our 3,2 array to a 2,3 array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.reshape(b,(1,-1)) #Reashape to a Row array
# Out:
# array([[1, 2, 3, 4, 5, 6]])

# %%
np.reshape(b,(-1,1)) #Rashape to a Column array
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %%
b<4
# Out:
# array([[ True,  True],
#        [ True, False],
#        [False, False]])

# %%
x = np.array([(1,2), (3,4)])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
y = np.array([(5,6),(7,8)])
y
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
x*y
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
x.dot(y) #matrix multiplication 
#First row multiplied by first column
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.arange(1, 9, step= 2)
# Out:
# array([1, 3, 5, 7])

# %%
np.arange(6).reshape(2,3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.linspace(1, 10, num= 5)
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
np.linspace(0, 2, 9)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
np.empty(3)
# Out:
# array([1., 1., 1.])

# %%
np.full((2,3), 4)
# Out:
# array([[4, 4, 4],
#        [4, 4, 4]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
t= np.arange(3)
t
# Out:
# array([0, 1, 2])

# %% [markdown]
# Universal functions

# %%
np.sqrt(3)
# Out:
# np.float64(1.7320508075688772)

# %%
np.exp(t)
# Out:
# array([1.        , 2.71828183, 7.3890561 ])

# %%
p = np.array([(1, 5, 3), (8, 2, 6)])
p
# Out:
# array([[1, 5, 3],
#        [8, 2, 6]])

# %%
p.sum(axis=0)
# Out:
# array([9, 7, 9])

# %%
p.sum(axis=1)
# Out:
# array([ 9, 16])

# %%
p.min(axis=0)
# Out:
# array([1, 2, 3])

# %%
p.min(axis=1)
# Out:
# array([1, 2])

# %%
np.sort(p, axis=None)
# Out:
# array([1, 2, 3, 5, 6, 8])

# %%
np.sort(p)
# Out:
# array([[1, 3, 5],
#        [2, 6, 8]])

# %%
np.random.seed(1)
np.random.randint(5)
# Out:
# 3

# %%
np.random.randint(4, size=(2,3))
# Out:
# array([[0, 0, 3],
#        [1, 3, 1]], dtype=int32)

# %%
np.random.rand(5)
# Out:
# array([0.14675589, 0.09233859, 0.18626021, 0.34556073, 0.39676747])

# %%
np.random.rand(3)
# Out:
# array([0.53881673, 0.41919451, 0.6852195 ])

# %%
np.random.uniform(0, 4, size=(2, 3))
# Out:
# array([[0.817809  , 3.51246975, 0.10955037],
#        [2.68187004, 1.66921921, 2.23475931]])

# %%
np.random.rand(3)
# Out:
# array([0.14038694, 0.19810149, 0.80074457])

# %%
x = np.sqrt(0.2)*np.random.randn(100000) + 5.0
plt.hist(x, bins = 100);
